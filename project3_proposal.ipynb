# %%
# Project 3 type choice - Data Science

# %%
# Data Sets to be Used :

# %%
## 1st Data set :

print("Direct 1st Data Set link on Kaggle - https://www.kaggle.com/stefanoleone992/imdb-extensive-dataset")
# Out:
# Direct 1st Data Set link on Kaggle - https://www.kaggle.com/stefanoleone992/imdb-extensive-dataset

# %%
import pandas as pd

# %%
data_set_1 = pd.read_csv("IMDb movies.csv")

# %%
data_set_1.head()
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000574                        The Story of the Kelly Gang
# 1     tt0001892                                     Den sorte drøm
# 2     tt0002101                                          Cleopatra
# 3     tt0002130                                          L'Inferno
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
#
#                                       original_title  year date_published  \
# 0                        The Story of the Kelly Gang  1906     1906-12-26
# 1                                     Den sorte drøm  1911     1911-08-19
# 2                                          Cleopatra  1912     1912-11-13
# 3                                          L'Inferno  1911     1911-03-06
# 4  From the Manger to the Cross; or, Jesus of Naz...  1912           1913
#
#                        genre  duration           country language  \
# ...

# %%
data_set_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81273 entries, 0 to 81272
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          81273 non-null  object
#  1   title                  81273 non-null  object
#  2   original_title         81273 non-null  object
#  3   year                   81273 non-null  int64
#  4   date_published         81273 non-null  object
#  5   genre                  81273 non-null  object
#  6   duration               81273 non-null  int64
#  7   country                81234 non-null  object
#  8   language               80518 non-null  object
#  9   director               81200 non-null  object
#  10  writer                 79780 non-null  object
#  11  production_company     76948 non-null  object
#  12  actors                 81207 non-null  object
#  13  description            78843 non-null  object
# ...

# %%
## 2nd Data set :

print("Direct 2nd Data Set link on Kaggle - https://www.kaggle.com/unanimad/the-oscar-award")
# Out:
# Direct 2nd Data Set link on Kaggle - https://www.kaggle.com/unanimad/the-oscar-award

# %%
data_set_2 = pd.read_csv("the_oscar_award.csv")

# %%
data_set_2.head()
# Out:
#    year_film  year_ceremony  ceremony category                 name  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess
# 1       1927           1928         1    ACTOR        Emil Jannings
# 2       1927           1928         1  ACTRESS       Louise Dresser
# 3       1927           1928         1  ACTRESS         Janet Gaynor
# 4       1927           1928         1  ACTRESS       Gloria Swanson
#
#                film  winner
# 0         The Noose   False
# 1  The Last Command    True
# 2   A Ship Comes In   False
# 3        7th Heaven    True
# 4    Sadie Thompson   False

# %%
data_set_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10395 entries, 0 to 10394
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year_film      10395 non-null  int64
#  1   year_ceremony  10395 non-null  int64
#  2   ceremony       10395 non-null  int64
#  3   category       10395 non-null  object
#  4   name           10395 non-null  object
#  5   film           10091 non-null  object
#  6   winner         10395 non-null  bool
# dtypes: bool(1), int64(3), object(3)
# memory usage: 497.5+ KB

# %%
# Objective of the Project 3 :

# %%
##  1) Grouping both of these data sets into 1
##  2) Cleaning the data where needed to reduce risk of potential innacuracies in findings
##  3) To find out which Film Genres are most successful based both on Average Viewers vote as well as the Won Oscars
##  4) To find out which Film Genres are best to invest in at present based on Budget and Income
##  5) To find out when it is potentially the best time to Release a Film based on the Release date
##  6) To find out which Production Companies released the greatest ammount of most successful films in the last 3 years
##  7) Visualise these Findings
